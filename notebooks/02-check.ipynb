# %%
cd ..
# Out:
# /home/alex/tmp/yourtube
# /home/alex/tmp/yourtube/.venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
from src.imports import *
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
df_1 = pd.read_csv('data/tables/videos.csv')
df_1
# Out:
#          id_video                                              title  \
# 0     6a1fLEToyvU   25 Math explainers you may enjoy | SoME3 results
# 1     aXRTczANuIs  This equation explains (nearly) all of optics ...
# 2     QCX62YJCmGk  This demo surprised me (a lot) | Barber pole, ...
# 3     d_qvLDhkg00  A pretty reason why Gaussian + Gaussian = Gaus...
# 4     YtkIWDE36qU  This pattern breaks, but for a good reason | M...
# ...           ...                                                ...
# 3555  sDmu2s570C4  Radicalization on YouTube (ft. Manoel Horta Ri...
# 3556  zxzBJSfJa4Q  Federated learning (ft. Sai Praneeth Reddy Kar...
# 3557  bSaer3LvmPk  Proof of Bandwith: An Alternative to Proof of ...
# 3558  8Wr20InFjTs  Interactive comparison based search: who-is-th...
# 3559  5r1YYTKjaVA  Protean: A General Purpose Decentralized Compu...
#
#                 author                  published   stars    views  \
# 0          3Blue1Brown  2023-10-07 14:28:37+00:00  102520   440699
# ...

# %%
df_0 = pd.read_csv('data/tables/videos_deprecated.csv')
df_0
# Out:
#          id_video                                              title  \
# 0     6a1fLEToyvU   25 Math explainers you may enjoy | SoME3 results
# 1     aXRTczANuIs  This equation explains (nearly) all of optics ...
# 2     QCX62YJCmGk  This demo surprised me (a lot) | Barber pole, ...
# 3     d_qvLDhkg00  A pretty reason why Gaussian + Gaussian = Gaus...
# 4     YtkIWDE36qU  This pattern breaks, but for a good reason | M...
# ...           ...                                                ...
# 3555  sDmu2s570C4  Radicalization on YouTube (ft. Manoel Horta Ri...
# 3556  zxzBJSfJa4Q  Federated learning (ft. Sai Praneeth Reddy Kar...
# 3557  bSaer3LvmPk  Proof of Bandwith: An Alternative to Proof of ...
# 3558  8Wr20InFjTs  Interactive comparison based search: who-is-th...
# 3559  5r1YYTKjaVA  Protean: A General Purpose Decentralized Compu...
#
#                 author                  published   stars    views  \
# 0          3Blue1Brown  2023-10-07 14:28:37+00:00  102520   440699
# ...

# %%
df = pd.concat([df_0, df_1], axis=0, ignore_index=True)

# %%
df
# Out:
#          id_video                                              title  \
# 0     6a1fLEToyvU   25 Math explainers you may enjoy | SoME3 results
# 1     aXRTczANuIs  This equation explains (nearly) all of optics ...
# 2     QCX62YJCmGk  This demo surprised me (a lot) | Barber pole, ...
# 3     d_qvLDhkg00  A pretty reason why Gaussian + Gaussian = Gaus...
# 4     YtkIWDE36qU  This pattern breaks, but for a good reason | M...
# ...           ...                                                ...
# 7115  sDmu2s570C4  Radicalization on YouTube (ft. Manoel Horta Ri...
# 7116  zxzBJSfJa4Q  Federated learning (ft. Sai Praneeth Reddy Kar...
# 7117  bSaer3LvmPk  Proof of Bandwith: An Alternative to Proof of ...
# 7118  8Wr20InFjTs  Interactive comparison based search: who-is-th...
# 7119  5r1YYTKjaVA  Protean: A General Purpose Decentralized Compu...
#
#                 author                  published   stars    views  \
# 0          3Blue1Brown  2023-10-07 14:28:37+00:00  102520   440699
# ...

# %%
df.value_counts("id_video").sort_values(ascending=False)
# Out:
# id_video
# --41f-GXJJg    2
# -GToXhPm2Zo    2
# 0wAy0Kptq3c    2
# -H_Cr-bPFd8    2
# -5f8Kp0pLac    2
#               ..
# zumgy013oqk    2
# zwI4LxpNvZk    2
# zwjZjSatM7A    2
# zwxRwNntzEM    2
# zy-d-S5BVL4    2
# Name: count, Length: 3560, dtype: int64

# %%
df.sort_values("published", ascending=False)
# Out:
#          id_video                                              title  \
# 2133  QXkYdLmUCNs  🔴 [LIVE] LA FRANCE, GRANDE FAVORITE POUR L'EUR...
# 5693  QXkYdLmUCNs  🔴 [LIVE] LA FRANCE, GRANDE FAVORITE POUR L'EUR...
# 1197  jU6SNrkYpqE  Learn one simple defense against 1.c4, 1.Nf3, ...
# 4757  jU6SNrkYpqE  Learn one simple defense against 1.c4, 1.Nf3, ...
# 6503  gBl9bedqu0k          Brut.Book — "Submersion" par Bruno Patino
# ...           ...                                                ...
# 1832  r6vFKLSKptE      Shattered Glass @ First Talent Show Rehearsal
# 1393  r4xDVuOyTGE             Bande annonce spectacle jeremy ferrari
# 4953  r4xDVuOyTGE             Bande annonce spectacle jeremy ferrari
# 4954  hUZC5nzSPiY                 Jeremy Ferrari Jt france3 National
# 1394  hUZC5nzSPiY                 Jeremy Ferrari Jt france3 National
#
#              author                  published  stars  views  \
# 2133        Winamax  2023-11-22 13:09:38+00:00    985    367
# ...
